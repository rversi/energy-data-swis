# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(os.path.join('../RAW_DATA/conventional_power_plants_CH.csv'))
df['type']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 631   NaN
# 632   NaN
# 633   NaN
# 634   NaN
# 635   NaN
# 636   NaN
# 637   NaN
# 638   NaN
# 639   NaN
# 640   NaN
# 641   NaN
# 642   NaN
# 643   NaN
# 644   NaN
# 645   NaN
# 646   NaN
# 647   NaN
# 648   NaN
# 649   NaN
# 650   NaN
# 651   NaN
# 652   NaN
# 653   NaN
# 654   NaN
# 655   NaN
# 656   NaN
# 657   NaN
# 658   NaN
# 659   NaN
# 660   NaN
# Name: type, Length: 661, dtype: float64

# %%
# %matplotlib notebook
plt.figure('Electrical capacity per year',figsize=(8,5))
plt.plot(df.groupby(['commissioned'])['capacity'].sum(),'-o',color='black',alpha=0.4)
plt.grid(color='xkcd:silver')
plt.xlabel('ANNÉE')
plt.ylabel('PUISSANCE')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df['technology'].unique()
# Out:
# array(['Run-of-river', 'Reservoir', 'Pumped storage',
#        'Pumped storage with natural inflow', 'Steam turbine'], dtype=object)
