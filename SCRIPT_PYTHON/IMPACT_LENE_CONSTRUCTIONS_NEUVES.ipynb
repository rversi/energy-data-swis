# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(os.path.join('SWISS ENERGY DATA','Données nbre bâtiments par agents énergétiques'))
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ep1919=df[df['Époque de construction']=='Avant 1919']
ep1945=df[df['Époque de construction']=='1919-1945']
ep1960=df[df['Époque de construction']=='1946-1960']
ep1970=df[df['Époque de construction']=='1961-1970']
ep1980=df[df['Époque de construction']=='1971-1980']
ep1990=df[df['Époque de construction']=='1981-1990']
ep2000=df[df['Époque de construction']=='1991-2000']
ep2005=df[df['Époque de construction']=='2001-2005']
ep2015=df[df['Époque de construction']=='2006-2015']

# %%
# %matplotlib notebook
plt.figure('VAUD avant 1919')
plt.pie(ep1919[(ep1919['Zone géographique']=='Vaud')&(ep1919['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum())
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1084446988349979,
#  1.1004021321348481,
#  -1.1093780572505791,
#  1.1044204617786626)

# %%
plt.figure('Époque 1945')
plt.pie(ep1945[(ep1945['Zone géographique']=='Vaud')&(ep1945['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum())
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1101680870645669,
#  1.1004841946221222,
#  -1.111527976573649,
#  1.1081212155088978)

# %%
plt.figure('Époque 1970')
plt.pie(ep1970[(ep1970['Zone géographique']=='Vaud')&(ep1970['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum())
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1191518822149016,
#  1.1009119943911858,
#  -1.1175446865876073,
#  1.1030646172010379)

# %%
plt.figure('Époque 2000')
plt.pie(ep2000[(ep2000['Zone géographique']=='Vaud')&(ep2000['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum())
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1320742236235997,
#  1.1015273439820761,
#  -1.1092478357775279,
#  1.1278093004269223)

# %%
plt.figure()
plt.pie(ep2005[(ep2005['Zone géographique']=='Vaud')&(ep2005['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum(),labels=sorted(ep2005['Agent énergétique chauffage'].unique().tolist()))
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1078882086697686,
#  1.1003756289842748,
#  -1.1052632570567344,
#  1.103399695542004)

# %%
plt.figure()
plt.pie(ep2015[(ep2015['Zone géographique']=='Vaud')&(ep2015['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum(),labels=sorted(ep2015['Agent énergétique chauffage'].unique().tolist()))
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1271037815671257,
#  1.1012906591357057,
#  -1.1074688675021496,
#  1.1024437251200221)

# %%
plt.figure()
plt.pie(ep2015[(ep2015['Zone géographique']=='Genève')&(ep2015['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum(),labels=sorted(ep2015['Agent énergétique chauffage'].unique().tolist()))
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1111824495819731,
#  1.1005324975991415,
#  -1.1110519408492912,
#  1.1096839075706444)

# %%
ep2005.head()
# Out:
#     ID Canton Zone géographique      Type d'habitation  \
# 49          0            Suisse  Maisons individuelles
# 50          0            Suisse  Maisons individuelles
# 51          0            Suisse  Maisons individuelles
# 52          0            Suisse  Maisons individuelles
# 53          0            Suisse  Maisons individuelles
#
#    Agent énergétique chauffage Agent énergétique ECS  Année  \
# 49             Mazout (chauf.)      Mazout (eau ch.)   2009
# 50             Mazout (chauf.)      Mazout (eau ch.)   2010
# 51             Mazout (chauf.)      Mazout (eau ch.)   2011
# 52             Mazout (chauf.)      Mazout (eau ch.)   2012
# 53             Mazout (chauf.)      Mazout (eau ch.)   2013
#
#    Époque de construction  Nombre de bâtiments
# 49              2001-2005                11600
# 50              2001-2005                11773
# 51              2001-2005                11516
# 52              2001-2005                11595
# ...

# %%
plt.figure()
plt.pie(ep2015[(ep2015['Zone géographique']=='Bern / Berne')&(ep2015['Année']==2015)].groupby('Agent énergétique chauffage')['Nombre de bâtiments'].sum(),labels=sorted(ep2015['Agent énergétique chauffage'].unique().tolist()))
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1085171410934471,
#  1.1004055819407286,
#  -1.1115210768547781,
#  1.1048242912634367)

# %%
zone='Genève'

charbon=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Charbon (chauf.)')].groupby('Année').sum()
charbon['bâtiment par an']=charbon['Nombre de bâtiments']

for i in range(1,7):    
    charbon.iloc[i,1]-=charbon.iloc[i-1,2]
charbon=charbon.iloc[1:7,1]

mazout=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Mazout (chauf.)')].groupby('Année').sum()
mazout['bâtiment par an']=mazout['Nombre de bâtiments']

for i in range(1,7):    
    mazout.iloc[i,1]-=mazout.iloc[i-1,2]
mazout=mazout.iloc[1:7,1]

gaz=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Gaz (chauf.)')].groupby('Année').sum()
gaz['bâtiment par an']=gaz['Nombre de bâtiments']

for i in range(1,7):    
    gaz.iloc[i,1]-=gaz.iloc[i-1,2]
gaz=gaz.iloc[1:7,1]

pac=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Pompe à chaleur (chauf.)')].groupby('Année').sum()
pac['bâtiment par an']=pac['Nombre de bâtiments']

for i in range(1,7):    
    pac.iloc[i,1]-=pac.iloc[i-1,2]
pac=pac.iloc[1:7,1]

elec=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Electricité (chauf.)')].groupby('Année').sum()
elec['bâtiment par an']=elec['Nombre de bâtiments']

for i in range(1,7):    
    elec.iloc[i,1]-=elec.iloc[i-1,2]
elec=elec.iloc[1:7,1]

bois=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Bois (chauf.)')].groupby('Année').sum()
bois['bâtiment par an']=bois['Nombre de bâtiments']

for i in range(1,7):    
    bois.iloc[i,1]-=bois.iloc[i-1,2]
bois=bois.iloc[1:7,1]

sol=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Capteur solaire (chauf.)')].groupby('Année').sum()
sol['bâtiment par an']=sol['Nombre de bâtiments']

for i in range(1,7):    
    sol.iloc[i,1]-=sol.iloc[i-1,2]
sol=sol.iloc[1:7,1]

cad=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Chaleur à distance (chauf.)')].groupby('Année').sum()
cad['bâtiment par an']=cad['Nombre de bâtiments']

for i in range(1,7):    
    cad.iloc[i,1]-=cad.iloc[i-1,2]
cad=cad.iloc[1:7,1]
cad.replace(to_replace=-10,value=0,inplace=True)

aut=ep2015[(ep2015['Zone géographique']==zone)&(ep2015['Agent énergétique chauffage']=='Autre agent énergétique (chauf.)')].groupby('Année').sum()
aut['bâtiment par an']=aut['Nombre de bâtiments']

for i in range(1,7):    
    aut.iloc[i,1]-=aut.iloc[i-1,2]
aut=aut.iloc[1:7,1]

total=ep2015[ep2015['Zone géographique']==zone].groupby(['Année']).sum()

total['Total']=total['Nombre de bâtiments']
for i in range(1,7):    
    total.iloc[i,1]-=total.iloc[i-1,2]
total=total.iloc[1:7,1]

plt.figure('Évolution de la part des nouveaux agents énergétiques installés dans le canton de '+zone,figsize=(8,6))

width=0.35
N=np.arange(6)

plt.bar(N,100*charbon/total,width,color='black',label='Charbon')
plt.bar(N,100*mazout/total,width,bottom=100*charbon/total,color='grey',label='Mazout')
plt.bar(N,100*gaz/total,width,bottom=100*charbon/total+100*mazout/total,color='silver',label='Gaz')
plt.bar(N,100*pac/total,width,bottom=100*charbon/total+100*mazout/total+100*gaz/total,label='PAC')
plt.bar(N,100*elec/total,width,bottom=100*charbon/total+100*mazout/total+100*gaz/total+100*pac/total,color='gold',label='Électricité')
plt.bar(N,100*bois/total,width,bottom=100*charbon/total+100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon',label='Bois')
plt.bar(N,100*sol/total,width,bottom=100*charbon/total+100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green',label='Solaire')
plt.bar(N,100*cad/total,width,bottom=100*charbon/total+100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total,label='CAD')
plt.bar(N,100*aut/total,width,bottom=100*charbon/total+100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red',label='Autres')
plt.xticks(N, ('2010', '2011','2012', '2013', "2014", '2015'),rotation=90)
plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
plt.legend(bbox_to_anchor=(0.95, 0.7),framealpha=1)
# Out:
# <img src="data:image/png;base64,..." width="994.5">

# %%
mazout=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Mazout (chauf.)')].groupby('Année').sum()
mazout['bâtiment par an']=mazout['Nombre de bâtiments']

for i in range(1,7):    
    mazout.iloc[i,1]-=mazout.iloc[i-1,2]
mazout=mazout.iloc[1:7,1]

gaz=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Gaz (chauf.)')].groupby('Année').sum()
gaz['bâtiment par an']=gaz['Nombre de bâtiments']

for i in range(1,7):    
    gaz.iloc[i,1]-=gaz.iloc[i-1,2]
gaz=gaz.iloc[1:7,1]

pac=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Pompe à chaleur (chauf.)')].groupby('Année').sum()
pac['bâtiment par an']=pac['Nombre de bâtiments']

for i in range(1,7):    
    pac.iloc[i,1]-=pac.iloc[i-1,2]
pac=pac.iloc[1:7,1]

elec=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Electricité (chauf.)')].groupby('Année').sum()
elec['bâtiment par an']=elec['Nombre de bâtiments']

for i in range(1,7):    
    elec.iloc[i,1]-=elec.iloc[i-1,2]
elec=elec.iloc[1:7,1]

bois=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Bois (chauf.)')].groupby('Année').sum()
bois['bâtiment par an']=bois['Nombre de bâtiments']

for i in range(1,7):    
    bois.iloc[i,1]-=bois.iloc[i-1,2]
bois=bois.iloc[1:7,1]

sol=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Capteur solaire (chauf.)')].groupby('Année').sum()
sol['bâtiment par an']=sol['Nombre de bâtiments']

for i in range(1,7):    
    sol.iloc[i,1]-=sol.iloc[i-1,2]
sol=sol.iloc[1:7,1]

cad=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Chaleur à distance (chauf.)')].groupby('Année').sum()
cad['bâtiment par an']=cad['Nombre de bâtiments']

for i in range(1,7):    
    cad.iloc[i,1]-=cad.iloc[i-1,2]
cad=cad.iloc[1:7,1]

aut=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique chauffage']=='Autre agent énergétique (chauf.)')].groupby('Année').sum()
aut['bâtiment par an']=aut['Nombre de bâtiments']

for i in range(1,7):    
    aut.iloc[i,1]-=aut.iloc[i-1,2]
aut=aut.iloc[1:7,1]

total=ep2015[ep2015['Zone géographique']=='Suisse'].groupby(['Année']).sum()

total['Total']=total['Nombre de bâtiments']
for i in range(1,7):    
    total.iloc[i,1]-=total.iloc[i-1,2]
total=total.iloc[1:7,1]

plt.figure('Évolution de la part des nouveaux agents énergétiques (chauf.) installés en Suisse',figsize=(8,6))

width=0.35
N=np.arange(6)

plt.bar(N,100*mazout/total,width,color='grey')
plt.bar(N,100*gaz/total,width,bottom=100*mazout/total,color='silver')
plt.bar(N,100*pac/total,width,bottom=100*mazout/total+100*gaz/total)
plt.bar(N,100*elec/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total,color='gold')
plt.bar(N,100*bois/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon')
plt.bar(N,100*sol/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green')
plt.bar(N,100*cad/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total)
plt.bar(N,100*aut/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red')
plt.xticks(N, ('2010', '2011','2012', '2013', '2014', '2015'),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
mazout=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Mazout (eau ch.)')].groupby('Année').sum()
mazout['bâtiment par an']=mazout['Nombre de bâtiments']

for i in range(1,7):    
    mazout.iloc[i,1]-=mazout.iloc[i-1,2]
mazout=mazout.iloc[1:7,1]

gaz=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Gaz (eau ch.)')].groupby('Année').sum()
gaz['bâtiment par an']=gaz['Nombre de bâtiments']

for i in range(1,7):    
    gaz.iloc[i,1]-=gaz.iloc[i-1,2]
gaz=gaz.iloc[1:7,1]

pac=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Pompe à chaleur (eau ch.)')].groupby('Année').sum()
pac['bâtiment par an']=pac['Nombre de bâtiments']

for i in range(1,7):    
    pac.iloc[i,1]-=pac.iloc[i-1,2]
pac=pac.iloc[1:7,1]

elec=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Electricité (eau ch.)')].groupby('Année').sum()
elec['bâtiment par an']=elec['Nombre de bâtiments']

for i in range(1,7):    
    elec.iloc[i,1]-=elec.iloc[i-1,2]
elec=elec.iloc[1:7,1]

bois=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Bois (eau ch.)')].groupby('Année').sum()
bois['bâtiment par an']=bois['Nombre de bâtiments']

for i in range(1,7):    
    bois.iloc[i,1]-=bois.iloc[i-1,2]
bois=bois.iloc[1:7,1]

sol=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Capteur solaire (eau ch.)')].groupby('Année').sum()
sol['bâtiment par an']=sol['Nombre de bâtiments']

for i in range(1,7):    
    sol.iloc[i,1]-=sol.iloc[i-1,2]
sol=sol.iloc[1:7,1]

cad=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Chaleur à distance (eau ch.)')].groupby('Année').sum()
cad['bâtiment par an']=cad['Nombre de bâtiments']

for i in range(1,7):    
    cad.iloc[i,1]-=cad.iloc[i-1,2]
cad=cad.iloc[1:7,1]

aut=ep2015[(ep2015['Zone géographique']=='Suisse')&(ep2015['Agent énergétique ECS']=='Autre agent énergétique (eau ch.)')].groupby('Année').sum()
aut['bâtiment par an']=aut['Nombre de bâtiments']

for i in range(1,7):    
    aut.iloc[i,1]-=aut.iloc[i-1,2]
aut=aut.iloc[1:7,1]

total=ep2015[ep2015['Zone géographique']=='Suisse'].groupby(['Année']).sum()

total['Total']=total['Nombre de bâtiments']
for i in range(1,7):    
    total.iloc[i,1]-=total.iloc[i-1,2]
total=total.iloc[1:7,1]

plt.figure('Évolution de la part des nouveaux agents énergétiques (ECS) installés en Suisse',figsize=(8,6))

width=0.35
N=np.arange(6)

plt.bar(N,100*mazout/total,width,color='grey')
plt.bar(N,100*gaz/total,width,bottom=100*mazout/total,color='silver')
plt.bar(N,100*pac/total,width,bottom=100*mazout/total+100*gaz/total)
plt.bar(N,100*elec/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total,color='gold')
plt.bar(N,100*bois/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon')
plt.bar(N,100*sol/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green')
plt.bar(N,100*cad/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total)
plt.bar(N,100*aut/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red')
plt.xticks(N, ('2010', '2011','2012', '2013', '2014', '2015'),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ep2015[ep2015['Année']==2015].groupby(['Zone géographique']).sum()
# Out:
#                                   ID Canton   Année  Nombre de bâtiments
# Zone géographique
# Aargau                                 6157  652860                15927
# Appenzell Ausserrhoden                 4861  652860                  963
# Appenzell Innerrhoden                  5185  652860                  410
# Basel-Landschaft                       4213  652860                 5533
# Basel-Stadt                            3889  652860                  453
# Bern / Berne                            649  652860                15242
# Fribourg / Freiburg                    3241  652860                10612
# Genève                                 8101  652860                 3525
# Glarus                                 2593  652860                  682
# Graubünden / Grigioni / Grischun       5833  652860                 5654
# Jura                                   8424  652860                 1886
# Luzern                                  973  652860                 8003
# ...

# %%
mazout=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Mazout (chauf.)')].groupby(['Zone géographique']).sum()
mazout=mazout['Nombre de bâtiments']

gaz=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Gaz (chauf.)')].groupby(['Zone géographique']).sum()
gaz=gaz['Nombre de bâtiments']

pac=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Pompe à chaleur (chauf.)')].groupby(['Zone géographique']).sum()
pac=pac['Nombre de bâtiments']

elec=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Electricité (chauf.)')].groupby(['Zone géographique']).sum()
elec=elec['Nombre de bâtiments']

bois=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Bois (chauf.)')].groupby(['Zone géographique']).sum()
bois=bois['Nombre de bâtiments']

charbon=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Charbon (chauf.)')].groupby(['Zone géographique']).sum()
charbon=charbon['Nombre de bâtiments']

cad=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Chaleur à distance (chauf.)')].groupby(['Zone géographique']).sum()
cad=cad['Nombre de bâtiments']

sol=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Capteur solaire (chauf.)')].groupby(['Zone géographique']).sum()
sol=sol['Nombre de bâtiments']

aut=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Autre agent énergétique (chauf.)')].groupby(['Zone géographique']).sum()
aut=aut['Nombre de bâtiments']

total=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)].groupby(['Zone géographique']).sum()
total=total['Nombre de bâtiments']

plt.figure('Évolution de la part des nouveaux agents énergétiques (chauf.) installés par Canton',figsize=(8,6))

width=0.35
N=np.arange(26)

plt.bar(N,100*charbon/total,width,color='black')
plt.bar(N,100*mazout/total,width,bottom=100*charbon/total,color='grey')
plt.bar(N,100*gaz/total,width,bottom=100*charbon/total+100*mazout/total,color='silver')
plt.bar(N,100*pac/total,width,bottom=100*mazout/total+100*gaz/total)
plt.bar(N,100*elec/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total,color='gold')
plt.bar(N,100*bois/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon')
plt.bar(N,100*sol/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green')
plt.bar(N,100*cad/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total)
plt.bar(N,100*aut/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red')
plt.xticks(N, mazout.index.tolist(),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="808">

# %%
charbon=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique chauffage']=='Charbon (chauf.)')].groupby(['Zone géographique']).sum()
charbon=charbon['Nombre de bâtiments']

# %%
total=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)].groupby(['Zone géographique']).sum()
total=total['Nombre de bâtiments']
total
# Out:
# Zone géographique
# Aargau                              15927
# Appenzell Ausserrhoden                963
# Appenzell Innerrhoden                 410
# Basel-Landschaft                     5533
# Basel-Stadt                           453
# Bern / Berne                        15242
# Fribourg / Freiburg                 10612
# Genève                               3525
# Glarus                                682
# Graubünden / Grigioni / Grischun     5654
# Jura                                 1886
# Luzern                               8003
# Neuchâtel                            2055
# Nidwalden                             752
# Obwalden                              857
# Schaffhausen                         1774
# Schwyz                               3887
# Solothurn                            6197
# St. Gallen                           9918
# Thurgau                              7827
# Ticino                               6944
# Uri                                   789
# ...

# %%
mazout=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Mazout (eau ch.)')].groupby(['Zone géographique']).sum()
mazout=mazout['Nombre de bâtiments']

gaz=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Gaz (eau ch.)')].groupby(['Zone géographique']).sum()
gaz=gaz['Nombre de bâtiments']

pac=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Pompe à chaleur (eau ch.)')].groupby(['Zone géographique']).sum()
pac=pac['Nombre de bâtiments']

elec=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Electricité (eau ch.)')].groupby(['Zone géographique']).sum()
elec=elec['Nombre de bâtiments']

bois=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Bois (eau ch.)')].groupby(['Zone géographique']).sum()
bois=bois['Nombre de bâtiments']

charbon=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Charbon (eau ch.)')].groupby(['Zone géographique']).sum()
charbon=charbon['Nombre de bâtiments']

cad=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Chaleur à distance (eau ch.)')].groupby(['Zone géographique']).sum()
cad=cad['Nombre de bâtiments']

sol=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Capteur solaire (eau ch.)')].groupby(['Zone géographique']).sum()
sol=sol['Nombre de bâtiments']

aut=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)&(ep2015['Agent énergétique ECS']=='Autre agent énergétique (eau ch.)')].groupby(['Zone géographique']).sum()
aut=aut['Nombre de bâtiments']

total=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)].groupby(['Zone géographique']).sum()
total=total['Nombre de bâtiments']

plt.figure('Évolution de la part des nouveaux agents énergétiques (ECS) installés par Canton',figsize=(8,6))

width=0.35
N=np.arange(26)

plt.bar(N,100*charbon/total,width,color='black')
plt.bar(N,100*mazout/total,width,bottom=100*charbon/total,color='grey')
plt.bar(N,100*gaz/total,width,bottom=100*charbon/total+100*mazout/total,color='silver')
plt.bar(N,100*pac/total,width,bottom=100*mazout/total+100*gaz/total)
plt.bar(N,100*elec/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total,color='gold')
plt.bar(N,100*bois/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon')
plt.bar(N,100*sol/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green')
plt.bar(N,100*cad/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total)
plt.bar(N,100*aut/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red')
plt.xticks(N, mazout.index.tolist(),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
mazout=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Mazout (eau ch.)')].groupby(['Zone géographique']).sum()
mazout=mazout['Nombre de bâtiments']

gaz=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Gaz (eau ch.)')].groupby(['Zone géographique']).sum()
gaz=gaz['Nombre de bâtiments']

pac=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Pompe à chaleur (eau ch.)')].groupby(['Zone géographique']).sum()
pac=pac['Nombre de bâtiments']

elec=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Electricité (eau ch.)')].groupby(['Zone géographique']).sum()
elec=elec['Nombre de bâtiments']

bois=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Bois (eau ch.)')].groupby(['Zone géographique']).sum()
bois=bois['Nombre de bâtiments']

charbon=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Charbon (eau ch.)')].groupby(['Zone géographique']).sum()
charbon=charbon['Nombre de bâtiments']

cad=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Chaleur à distance (eau ch.)')].groupby(['Zone géographique']).sum()
cad=cad['Nombre de bâtiments']

sol=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Capteur solaire (eau ch.)')].groupby(['Zone géographique']).sum()
sol=sol['Nombre de bâtiments']

aut=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique ECS']=='Autre agent énergétique (eau ch.)')].groupby(['Zone géographique']).sum()
aut=aut['Nombre de bâtiments']

total=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)].groupby(['Zone géographique']).sum()
total=total['Nombre de bâtiments']

plt.figure('Évolution de la part des nouveaux agents énergétiques (ECS) installés 2005 - 2010 par Canton',figsize=(8,6))

width=0.35
N=np.arange(26)

plt.bar(N,100*charbon/total,width,color='black')
plt.bar(N,100*mazout/total,width,bottom=100*charbon/total,color='grey')
plt.bar(N,100*gaz/total,width,bottom=100*charbon/total+100*mazout/total,color='silver')
plt.bar(N,100*pac/total,width,bottom=100*mazout/total+100*gaz/total)
plt.bar(N,100*elec/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total,color='gold')
plt.bar(N,100*bois/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon')
plt.bar(N,100*sol/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green')
plt.bar(N,100*cad/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total)
plt.bar(N,100*aut/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red')
plt.xticks(N, mazout.index.tolist(),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
mazout=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Mazout (chauf.)')].groupby(['Zone géographique']).sum()
mazout=mazout['Nombre de bâtiments']

gaz=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Gaz (chauf.)')].groupby(['Zone géographique']).sum()
gaz=gaz['Nombre de bâtiments']

pac=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Pompe à chaleur (chauf.)')].groupby(['Zone géographique']).sum()
pac=pac['Nombre de bâtiments']

elec=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Electricité (chauf.)')].groupby(['Zone géographique']).sum()
elec=elec['Nombre de bâtiments']

bois=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Bois (chauf.)')].groupby(['Zone géographique']).sum()
bois=bois['Nombre de bâtiments']

charbon=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Charbon (chauf.)')].groupby(['Zone géographique']).sum()
charbon=charbon['Nombre de bâtiments']

cad=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Chaleur à distance (chauf.)')].groupby(['Zone géographique']).sum()
cad=cad['Nombre de bâtiments']

sol=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Capteur solaire (chauf.)')].groupby(['Zone géographique']).sum()
sol=sol['Nombre de bâtiments']

aut=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)&(ep2005['Agent énergétique chauffage']=='Autre agent énergétique (chauf.)')].groupby(['Zone géographique']).sum()
aut=aut['Nombre de bâtiments']

total=ep2005[(ep2005['Zone géographique']!='Suisse'].groupby(['Zone géographique']).sum()
total=total['Nombre de bâtiments']

plt.figure('Évolution de la part des nouveaux agents énergétiques (CHAUF) installés 2005 - 2010 par Canton',figsize=(8,6))

width=0.35
N=np.arange(26)

plt.bar(N,100*charbon/total,width,color='black')
plt.bar(N,100*mazout/total,width,bottom=100*charbon/total,color='grey')
plt.bar(N,100*gaz/total,width,bottom=100*charbon/total+100*mazout/total,color='silver')
plt.bar(N,100*pac/total,width,bottom=100*mazout/total+100*gaz/total)
plt.bar(N,100*elec/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total,color='gold')
plt.bar(N,100*bois/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total,color='maroon')
plt.bar(N,100*sol/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total,color='green')
plt.bar(N,100*cad/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total)
plt.bar(N,100*aut/total,width,bottom=100*mazout/total+100*gaz/total+100*pac/total+100*elec/total+100*bois/total+100*sol/total+100*cad/total,color='red')
plt.xticks(N, mazout.index.tolist(),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des agents installés par an (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
a=ep2015[(ep2015['Zone géographique']!='Suisse')&(ep2015['Année']==2015)].groupby(['Zone géographique']).sum()
a=a['Nombre de bâtiments']
b=ep2005[(ep2005['Zone géographique']!='Suisse')&(ep2005['Année']==2015)].groupby(['Zone géographique']).sum()
b=b['Nombre de bâtiments']
c=ep2000[(ep2000['Zone géographique']!='Suisse')&(ep2000['Année']==2015)].groupby(['Zone géographique']).sum()
c=c['Nombre de bâtiments']
d=ep1990[(ep1990['Zone géographique']!='Suisse')&(ep1990['Année']==2015)].groupby(['Zone géographique']).sum()
d=d['Nombre de bâtiments']
e=ep1980[(ep1980['Zone géographique']!='Suisse')&(ep1980['Année']==2015)].groupby(['Zone géographique']).sum()
e=e['Nombre de bâtiments']
f=ep1970[(ep1970['Zone géographique']!='Suisse')&(ep1970['Année']==2015)].groupby(['Zone géographique']).sum()
f=f['Nombre de bâtiments']
g=ep1960[(ep1960['Zone géographique']!='Suisse')&(ep1960['Année']==2015)].groupby(['Zone géographique']).sum()
g=g['Nombre de bâtiments']
h=ep1945[(ep1945['Zone géographique']!='Suisse')&(ep1945['Année']==2015)].groupby(['Zone géographique']).sum()
h=h['Nombre de bâtiments']
i=ep1919[(ep1919['Zone géographique']!='Suisse')&(ep1919['Année']==2015)].groupby(['Zone géographique']).sum()
i=i['Nombre de bâtiments']

tot=df[(df['Zone géographique']!='Suisse')&(df['Année']==2015)].groupby('Zone géographique').sum()['Nombre de bâtiments']

plt.figure('Âge du parc immobilier par Canton',figsize=(8,6))

width=0.35
N=np.arange(26)

plt.bar(N,100*a/tot,width,color='green')
plt.bar(N,100*b/tot,width,bottom=100*a/tot,color='green')
plt.bar(N,100*c/tot,width,bottom=100*a/tot+100*b/tot,color='silver')
plt.bar(N,100*d/tot,width,bottom=100*a/tot+100*b/tot+100*c/tot,color='grey')
plt.bar(N,100*e/tot,width,bottom=100*a/tot+100*b/tot+100*c/tot+100*d/tot,color='black')
plt.bar(N,100*f/tot,width,bottom=100*a/tot+100*b/tot+100*c/tot+100*d/tot+100*e/tot,color='black')
plt.bar(N,100*g/tot,width,bottom=100*a/tot+100*b/tot+100*c/tot+100*d/tot+100*e/tot+100*f/tot,color='black')
plt.bar(N,100*h/tot,width,bottom=100*a/tot+100*b/tot+100*c/tot+100*d/tot+100*e/tot+100*f/tot+100*g/tot,color='grey')
plt.bar(N,100*i/tot,width,bottom=100*a/tot+100*b/tot+100*c/tot+100*d/tot+100*e/tot+100*f/tot+100*g/tot+100*h/tot,color='grey')
plt.xticks(N, a.index.tolist(),rotation=90)

plt.yticks(np.arange(0, 101, 10),rotation=90)
plt.ylabel('Part des bâtiments par époque de construction (en %)')
plt.grid(color='xkcd:silver',alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="823">

# %%
a
# Out:
#                                   ID Canton   Année  Nombre de bâtiments
# Zone géographique
# Aargau                                 6157  652860                15927
# Appenzell Ausserrhoden                 4861  652860                  963
# Appenzell Innerrhoden                  5185  652860                  410
# Basel-Landschaft                       4213  652860                 5533
# Basel-Stadt                            3889  652860                  453
# Bern / Berne                            649  652860                15242
# Fribourg / Freiburg                    3241  652860                10612
# Genève                                 8101  652860                 3525
# Glarus                                 2593  652860                  682
# Graubünden / Grigioni / Grischun       5833  652860                 5654
# Jura                                   8424  652860                 1886
# Luzern                                  973  652860                 8003
# ...

# %%
a
# Out:
# Zone géographique
# Aargau                              15927
# Appenzell Ausserrhoden                963
# Appenzell Innerrhoden                 410
# Basel-Landschaft                     5533
# Basel-Stadt                           453
# Bern / Berne                        15242
# Fribourg / Freiburg                 10612
# Genève                               3525
# Glarus                                682
# Graubünden / Grigioni / Grischun     5654
# Jura                                 1886
# Luzern                               8003
# Neuchâtel                            2055
# Nidwalden                             752
# Obwalden                              857
# Schaffhausen                         1774
# Schwyz                               3887
# Solothurn                            6197
# St. Gallen                           9918
# Thurgau                              7827
# Ticino                               6944
# Uri                                   789
# ...

# %%
tot
# Out:
# Zone géographique
# Aargau                              1015471
# Appenzell Ausserrhoden               110543
# Appenzell Innerrhoden                 34344
# Basel-Landschaft                     454252
# Basel-Stadt                          164402
# Bern / Berne                        1583355
# Fribourg / Freiburg                  462836
# Genève                               294497
# Glarus                                92567
# Graubünden / Grigioni / Grischun     439350
# Jura                                 155394
# Luzern                               463124
# Neuchâtel                            210012
# Nidwalden                             53049
# Obwalden                              61203
# Schaffhausen                         127012
# Schwyz                               215347
# Solothurn                            462011
# St. Gallen                           765772
# Thurgau                              429573
# Ticino                               709482
# ...
