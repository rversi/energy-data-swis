# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
os.path.abspath(os.path.join('Données nbre bâtiments par agents énergétiques'))
# Out:
# '/Users/Roman/Desktop/CREM/Projets PY/Données nbre bâtiments par agents énergétiques'

# %%
df=pd.read_csv(os.path.abspath('/Users/Roman/Desktop/CREM/SWISS ENERGY DATA/Données nbre bâtiments par agents énergétiques'))
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df_suisse2015=df[(df['Zone géographique']=='Suisse')&(df['Année']==2015)]
df_valais2015=df[(df['Zone géographique']=='Valais / Wallis')&(df['Année']==2015)]
df_geneve2015=df[(df['Zone géographique']=='Genève')&(df['Année']==2015)]
df_vaud2015=df[(df['Zone géographique']=='Vaud')&(df['Année']==2015)]
df_zurich2015=df[(df['Zone géographique']=='Zürich')&(df['Année']==2015)]
df
# Out:
#         ID Canton Zone géographique  \
# 0               0            Suisse
# 1               0            Suisse
# 2               0            Suisse
# 3               0            Suisse
# 4               0            Suisse
# 5               0            Suisse
# 6               0            Suisse
# 7               0            Suisse
# 8               0            Suisse
# 9               0            Suisse
# 10              0            Suisse
# 11              0            Suisse
# 12              0            Suisse
# 13              0            Suisse
# 14              0            Suisse
# 15              0            Suisse
# 16              0            Suisse
# 17              0            Suisse
# 18              0            Suisse
# 19              0            Suisse
# 20              0            Suisse
# 21              0            Suisse
# 22              0            Suisse
# 23              0            Suisse
# 24              0            Suisse
# 25              0            Suisse
# 26              0            Suisse
# 27              0            Suisse
# 28              0            Suisse
# 29              0            Suisse
# ...           ...               ...
# 551094         26              Jura
# 551095         26              Jura
# 551096         26              Jura
# 551097         26              Jura
# 551098         26              Jura
# 551099         26              Jura
# 551100         26              Jura
# 551101         26              Jura
# 551102         26              Jura
# 551103         26              Jura
# 551104         26              Jura
# 551105         26              Jura
# 551106         26              Jura
# 551107         26              Jura
# 551108         26              Jura
# 551109         26              Jura
# 551110         26              Jura
# 551111         26              Jura
# 551112         26              Jura
# 551113         26              Jura
# 551114         26              Jura
# 551115         26              Jura
# 551116         26              Jura
# 551117         26              Jura
# 551118         26              Jura
# 551119         26              Jura
# 551120         26              Jura
# 551121         26              Jura
# 551122         26              Jura
# 551123         26              Jura
#
#                                    Type d'habitation  \
# 0                              Maisons individuelles
# 1                              Maisons individuelles
# 2                              Maisons individuelles
# 3                              Maisons individuelles
# 4                              Maisons individuelles
# 5                              Maisons individuelles
# 6                              Maisons individuelles
# 7                              Maisons individuelles
# 8                              Maisons individuelles
# 9                              Maisons individuelles
# 10                             Maisons individuelles
# 11                             Maisons individuelles
# 12                             Maisons individuelles
# 13                             Maisons individuelles
# 14                             Maisons individuelles
# 15                             Maisons individuelles
# 16                             Maisons individuelles
# 17                             Maisons individuelles
# 18                             Maisons individuelles
# 19                             Maisons individuelles
# 20                             Maisons individuelles
# 21                             Maisons individuelles
# 22                             Maisons individuelles
# 23                             Maisons individuelles
# 24                             Maisons individuelles
# 25                             Maisons individuelles
# 26                             Maisons individuelles
# 27                             Maisons individuelles
# 28                             Maisons individuelles
# 29                             Maisons individuelles
# ...                                              ...
# 551094  Bâtiments partiellement à usage d'habitation
# 551095  Bâtiments partiellement à usage d'habitation
# 551096  Bâtiments partiellement à usage d'habitation
# 551097  Bâtiments partiellement à usage d'habitation
# 551098  Bâtiments partiellement à usage d'habitation
# 551099  Bâtiments partiellement à usage d'habitation
# 551100  Bâtiments partiellement à usage d'habitation
Autre agent énergétique (chauf.)  Autre agent énergétique (eau ch.)
# 551123  Autre agent énergétique (chauf.)  Autre agent énergétique (eau ch.)
#
#         Année Époque de construction  Nombre de bâtiments
# 0        2009             Avant 1919                31081
# 1        2010             Avant 1919                31254
# 2        2011             Avant 1919                29698
# 3        2012             Avant 1919                29821
# 4        2013             Avant 1919                29337
# 5        2014             Avant 1919                29238
# 6        2015             Avant 1919                29596
# 7        2009              1919-1945                30965
# 8        2010              1919-1945                30802
# 9        2011              1919-1945                31844
# 10       2012              1919-1945                31406
# 11       2013              1919-1945                31071
# 12       2014              1919-1945                30670
# 13       2015              1919-1945                29959
# 14       2009              1946-1960                42703
# 15       2010              1946-1960                42490
# 16       2011              1946-1960                42114
# 17       2012              1946-1960                41701
# 18       2013              1946-1960                41330
# 19       2014              1946-1960                40858
# 20       2015              1946-1960                40395
# 21       2009              1961-1970                52942
# 22       2010              1961-1970                52635
# 23       2011              1961-1970                52188
# 24       2012              1961-1970                51732
# 25       2013              1961-1970                51348
# 26       2014              1961-1970                50894
# 27       2015              1961-1970                50682
# 28       2009              1971-1980                65761
# 29       2010              1971-1980                65361
# ...       ...                    ...                  ...
# 551094   2014              1971-1980                    0
# 551095   2015              1971-1980                    0
# 551096   2009              1981-1990                    0
# 551097   2010              1981-1990                    0
# 551098   2011              1981-1990                    0
# 551099   2012              1981-1990                    0
# 551100   2013              1981-1990                    0
# 551101   2014              1981-1990                    0
# 551102   2015              1981-1990                    0
# 551103   2009              1991-2000                    0
# 551104   2010              1991-2000                    0
# 551105   2011              1991-2000                    0
# 551106   2012              1991-2000                    0
# 551107   2013              1991-2000                    0
# 551108   2014              1991-2000                    0
# 551109   2015              1991-2000                    0
# 551110   2009              2001-2005                    0
# 551111   2010              2001-2005                    0
# 551112   2011              2001-2005                    0
# 551113   2012              2001-2005                    0
# 551114   2013              2001-2005                    0
# 551115   2014              2001-2005                    0
# 551116   2015              2001-2005                    0
# 551117   2009              2006-2015                    0
# 551118   2010              2006-2015                    0
# 551119   2011              2006-2015                    0
# 551120   2012              2006-2015                    0
# 551121   2013              2006-2015                    0
# 551122   2014              2006-2015                    0
# 551123   2015              2006-2015                    0
#
# [551124 rows x 8 columns]

# %%
df['Zone géographique'].unique()
# Out:
# array(['Suisse', 'Zürich', 'Bern / Berne', 'Luzern', 'Uri', 'Schwyz',
#        'Obwalden', 'Nidwalden', 'Glarus', 'Zug', 'Fribourg / Freiburg',
#        'Solothurn', 'Basel-Stadt', 'Basel-Landschaft', 'Schaffhausen',
#        'Appenzell Ausserrhoden', 'Appenzell Innerrhoden', 'St. Gallen',
#        'Graubünden / Grigioni / Grischun', 'Aargau', 'Thurgau', 'Ticino',
#        'Vaud', 'Valais / Wallis', 'Neuchâtel', 'Genève', 'Jura'], dtype=object)

# %%
fracs=df_suisse2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum()/df_suisse2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum().sum()
labels=['Autres','Bois','Capteurs solaires','CAD','Charbon','Électricité','Gaz','Mazout','PAC']
colors=['red','maroon','green','moccasin','black','yellow','silver','dimgray','gold']

fracs2=df_valais2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum()/df_valais2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum().sum()
fracs3=df_geneve2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum()/df_geneve2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum().sum()
fracs4=df_vaud2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum()/df_vaud2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum().sum()
fracs5=df_zurich2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum()/df_zurich2015.groupby(['Agent énergétique chauffage'])['Nombre de bâtiments'].sum().sum()

# %matplotlib notebook
plt.figure('SUISSE = Part (nbre) des agents énergétiques pour le chauffage en 2015',figsize=(8,8))
plt.pie(fracs,labels=labels,startangle=90,colors=colors,autopct='%.1f%%')
plt.axis('equal')

plt.figure('GENEVE = Part (nbre) des agents énergétiques pour le chauffage en 2015',figsize=(8,8))
plt.pie(fracs3,labels=labels,startangle=90,colors=colors,autopct='%.1f%%')

plt.figure('VALAIS = Part (nbre) des agents énergétiques pour le chauffage en 2015',figsize=(8,8))
plt.pie(fracs2,labels=labels,startangle=90,colors=colors,autopct='%.1f%%')

plt.figure('VAUD = Part (nbre) des agents énergétiques pour le chauffage en 2015',figsize=(8,8))
plt.pie(fracs4,labels=labels,startangle=90,colors=colors,autopct='%.1f%%')

plt.figure('ZURICH = Part (nbre) des agents énergétiques pour le chauffage en 2015',figsize=(8,8))
plt.pie(fracs5,labels=labels,startangle=90,colors=colors,autopct='%.1f%%')
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# ([<matplotlib.patches.Wedge at 0x10e14c5c0>,
#   <matplotlib.patches.Wedge at 0x10e9e97b8>,
#   <matplotlib.patches.Wedge at 0x10e9f29b0>,
#   <matplotlib.patches.Wedge at 0x10e9fcba8>,
#   <matplotlib.patches.Wedge at 0x10ea03da0>,
#   <matplotlib.patches.Wedge at 0x10ea0af98>,
#   <matplotlib.patches.Wedge at 0x10ea1c1d0>,
#   <matplotlib.patches.Wedge at 0x10ea253c8>,
#   <matplotlib.patches.Wedge at 0x10ea2b5c0>],
#  [<matplotlib.text.Text at 0x10e14cd68>,
#   <matplotlib.text.Text at 0x10e9e9f60>,
#   <matplotlib.text.Text at 0x10e9fc198>,
#   <matplotlib.text.Text at 0x10ea03390>,
#   <matplotlib.text.Text at 0x10ea0a588>,
#   <matplotlib.text.Text at 0x10ea13780>,
#   <matplotlib.text.Text at 0x10ea1c978>,
#   <matplotlib.text.Text at 0x10ea25b70>,
#   <matplotlib.text.Text at 0x10ea2bd68>],
#  [<matplotlib.text.Text at 0x10e9e9278>,
#   <matplotlib.text.Text at 0x10e9f2470>,
#   <matplotlib.text.Text at 0x10e9fc668>,
#   <matplotlib.text.Text at 0x10ea03860>,
#   <matplotlib.text.Text at 0x10ea0aa58>,
#   <matplotlib.text.Text at 0x10ea13c50>,
#   <matplotlib.text.Text at 0x10ea1ce48>,
#   <matplotlib.text.Text at 0x10ea2b080>,
#   <matplotlib.text.Text at 0x10ea34278>])

# %%
fracs1=df_suisse2015.groupby(['Agent énergétique ECS'])['Nombre de bâtiments'].sum()/df_suisse2015.groupby(['Agent énergétique ECS'])['Nombre de bâtiments'].sum().sum()
labels1=['Autres','Bois','Capteurs solaires','CAD','Charbon','Électricité','Gaz','Mazout','PAC']
colors=['red','maroon','green','moccasin','black','yellow','silver','dimgray','gold']

plt.figure('Part des agents énergétiques pour ECS en 2015',figsize=(8,8))

plt.pie(fracs1,labels=labels1,startangle=90,colors=colors,autopct='%.1f%%')
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="800">
# (-1.1201189660915249,
#  1.1122365687672728,
#  -1.1089843297951858,
#  1.1004278252283421)

# %%
100*df[df['Agent énergétique chauffage']=='Mazout (chauf.)'].groupby(['Année'])['Nombre de bâtiments'].sum()/df.groupby(['Année'])['Nombre de bâtiments'].sum()
# Out:
# Année
# 2009    52.031258
# 2010    51.404943
# 2011    50.668186
# 2012    50.007277
# 2013    49.343895
# 2014    48.516706
# 2015    47.589630
# Name: Nombre de bâtiments, dtype: float64
